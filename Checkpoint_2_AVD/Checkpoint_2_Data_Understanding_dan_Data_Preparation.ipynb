# %% [markdown]
# ###### **Fashion Products - Analisis Preferensi Fashion Products untuk Meningkatkan Strategi Pemasaran pada Platform Amazon**

# %% [markdown]
# Nama: Zahraturramadhani
#
# NIM: 2409116014
#
# Kelas: Sistem Informasi A'2024

# %% [markdown]
# #### Sumber Dataset:
#
# [Fashion Products Dataset](https://www.kaggle.com/datasets/bhanupratapbiswas/fashion-products)
#
# Dataset yang digunakan dalam analisis berisi informasi tentang produk fashion seperti User ID, Product ID, Product Name, Brand, Category, Price, Rating, Color, dan Size.

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## Membaca Data

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/praktikum/fashion_products.csv")

# %%
df
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 0         19           1        Dress  Adidas    Men's Fashion     40
# 1         97           2        Shoes     H&M  Women's Fashion     82
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 3         57           4        Shoes    Zara    Men's Fashion     23
# 4         79           5      T-shirt  Adidas    Men's Fashion     79
# ..       ...         ...          ...     ...              ...    ...
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 0    1.043159   Black   XL
# 1    4.026416   Black    L
# 2    3.337938  Yellow   XL
# ...

# %% [markdown]
# ## Menampilkan Keseluruhan Data

# %%
print("----------------------------")
print("Menampilkan keseluruhan data")
print("----------------------------")
print(df.to_string())
# Out:
# ----------------------------
# Menampilkan keseluruhan data
# ----------------------------
#      User ID  Product ID Product Name   Brand         Category  Price    Rating   Color Size
# 0         19           1        Dress  Adidas    Men's Fashion     40  1.043159   Black   XL
# 1         97           2        Shoes     H&M  Women's Fashion     82  4.026416   Black    L
# 2         25           3        Dress  Adidas  Women's Fashion     44  3.337938  Yellow   XL
# 3         57           4        Shoes    Zara    Men's Fashion     23  1.049523   White    S
# 4         79           5      T-shirt  Adidas    Men's Fashion     79  4.302773   Black    M
# 5         98           6        Dress  Adidas    Men's Fashion     47  1.379566  Yellow    L
# 6         16           7        Jeans   Gucci    Men's Fashion     37  1.356750   White   XL
# 7         63           8      Sweater    Zara    Kids' Fashion     64  4.360303    Blue   XL
# ...

# %% [markdown]
# ## Mengecek Struktur Data

# %% [markdown]
# 1. Menampilkan 10 baris pertama dataset

# %%
print("------------------------------------")
print("Menampilkan 10 baris pertama dataset")
print("------------------------------------")
df.head(10)
# Out:
# ------------------------------------
# Menampilkan 10 baris pertama dataset
# ------------------------------------
#    User ID  Product ID Product Name   Brand         Category  Price    Rating  \
# 0       19           1        Dress  Adidas    Men's Fashion     40  1.043159
# 1       97           2        Shoes     H&M  Women's Fashion     82  4.026416
# 2       25           3        Dress  Adidas  Women's Fashion     44  3.337938
# 3       57           4        Shoes    Zara    Men's Fashion     23  1.049523
# 4       79           5      T-shirt  Adidas    Men's Fashion     79  4.302773
# 5       98           6        Dress  Adidas    Men's Fashion     47  1.379566
# 6       16           7        Jeans   Gucci    Men's Fashion     37  1.356750
# 7       63           8      Sweater    Zara    Kids' Fashion     64  4.360303
# 8       96           9      Sweater     H&M    Men's Fashion     53  4.466182
# 9       36          10      T-shirt    Zara    Kids' Fashion     55  4.093234
# ...

# %% [markdown]
# 2. Menampilkan 10 baris terakhir dataset

# %%
print("--------------------------------------")
print("Menampilkan 10 baris terakhir  dataset")
print("--------------------------------------")
df.tail(10)
# Out:
# --------------------------------------
# Menampilkan 10 baris terakhir  dataset
# --------------------------------------
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 990       60         991        Shoes    Nike    Kids' Fashion     25
# 991       42         992      T-shirt   Gucci  Women's Fashion     91
# 992       89         993        Shoes     H&M  Women's Fashion     33
# 993       59         994      Sweater     H&M    Men's Fashion     89
# 994       34         995      Sweater  Adidas    Kids' Fashion     58
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 990  4.972677     Red    L
# ...

# %% [markdown]
# 3. Menampilkan ringkasan informasi dataset

# %%
print("---------------------------------------")
print("Menampilkan ringkasan informasi dataset")
print("---------------------------------------")
df.info()
# Out:
# ---------------------------------------
# Menampilkan ringkasan informasi dataset
# ---------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User ID       1000 non-null   int64
#  1   Product ID    1000 non-null   int64
#  2   Product Name  1000 non-null   object
#  3   Brand         1000 non-null   object
#  4   Category      1000 non-null   object
#  5   Price         1000 non-null   int64
#  6   Rating        1000 non-null   float64
#  7   Color         1000 non-null   object
#  8   Size          1000 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ KB

# %% [markdown]
# 4. Menampilkan jumlah baris dan kolom

# %%
print("------------------------------------------")
print("Menampilkan jumlah baris dan kolom dataset")
print("------------------------------------------")
df.shape
# Out:
# ------------------------------------------
# Menampilkan jumlah baris dan kolom dataset
# ------------------------------------------
# (1000, 9)

# %% [markdown]
# 5. Menampilkan tipe data setiap kolom

# %%
print("------------------------------------------")
print("Menampilkan tipe data setiap kolom dataset")
print("------------------------------------------")
df.dtypes
# Out:
# ------------------------------------------
# Menampilkan tipe data setiap kolom dataset
# ------------------------------------------
# User ID           int64
# Product ID        int64
# Product Name     object
# Brand            object
# Category         object
# Price             int64
# Rating          float64
# Color            object
# Size             object
# dtype: object

# %% [markdown]
# ## Statistik Deskriptif

# %% [markdown]
# 1. Menampilkan statistik ringkasan dataset

# %%
print("---------------------------------")
print("Menampilkan statistik deskriptif ")
print("---------------------------------")
df.describe()
# Out:
# ---------------------------------
# Menampilkan statistik deskriptif
# ---------------------------------
#           User ID   Product ID        Price       Rating
# count  1000.00000  1000.000000  1000.000000  1000.000000
# mean     50.41900   500.500000    55.785000     2.993135
# std      28.78131   288.819436    26.291748     1.153185
# min       1.00000     1.000000    10.000000     1.000967
# 25%      26.00000   250.750000    33.000000     1.992786
# 50%      50.00000   500.500000    57.000000     2.984003
# 75%      75.00000   750.250000    78.250000     3.985084
# max     100.00000  1000.000000   100.000000     4.987964

# %% [markdown]
# 2. Menghitung jumlah kemunculan nilai unik dalam kolom tertentu

# %%
kolom_tertentu = "Rating"
if kolom_tertentu in df.columns:
    print(f"\nMenghitung jumlah kemunculan nilai unik dalam kolom '{kolom_tertentu}':")
    print(df[kolom_tertentu].value_counts())
else:
    print(f"\nKolom '{kolom_tertentu}' tidak ditemukan dalam dataset.")
# Out:
# Menghitung jumlah kemunculan nilai unik dalam kolom 'Rating':
# Rating
# 1.043159    1
# 2.958263    1
# 1.024990    1
# 2.689886    1
# 1.533612    1
#            ..
# 1.804017    1
# 1.246472    1
# 4.473673    1
# 3.979717    1
# 3.093553    1
# Name: count, Length: 1000, dtype: int64

# %% [markdown]
# 3. Menghitung rata-rata dataset

# %%
print("-----------------------------")
print("Menghitung rata-rata dataset:")
print("-----------------------------")
print(df.mean(numeric_only=True))
# Out:
# -----------------------------
# Menghitung rata-rata dataset:
# -----------------------------
# User ID        50.419000
# Product ID    500.500000
# Price          55.785000
# Rating          2.993135
# dtype: float64

# %% [markdown]
# 4. Menghitung median dataset

# %%
print("--------------------------")
print("Menghitung median dataset:")
print("--------------------------")
print(df.median(numeric_only=True))
# Out:
# --------------------------
# Menghitung median dataset:
# --------------------------
# User ID        50.000000
# Product ID    500.500000
# Price          57.000000
# Rating          2.984003
# dtype: float64

# %% [markdown]
# 5. Menghitung standar deviasi dataset

# %%
print("-----------------------------------")
print("Menghitung standar deviasi dataset:")
print("-----------------------------------")
print(df.std(numeric_only=True))
# Out:
# -----------------------------------
# Menghitung standar deviasi dataset:
# -----------------------------------
# User ID        28.781310
# Product ID    288.819436
# Price          26.291748
# Rating          1.153185
# dtype: float64

# %% [markdown]
# 6. Menghitung korelasi antar kolom numerik

# %%
print("----------------------------------------")
print("Menghitung korelasi antar kolom numerik:")
print("----------------------------------------")
print(df.corr(numeric_only=True))
# Out:
# ----------------------------------------
# Menghitung korelasi antar kolom numerik:
# ----------------------------------------
#              User ID  Product ID     Price    Rating
# User ID     1.000000   -0.021075  0.003363  0.044837
# Product ID -0.021075    1.000000  0.034602  0.033896
# Price       0.003363    0.034602  1.000000  0.033927
# Rating      0.044837    0.033896  0.033927  1.000000

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## Membaca Data

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/praktikum/fashion_products.csv")

# %%
df
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 0         19           1        Dress  Adidas    Men's Fashion     40
# 1         97           2        Shoes     H&M  Women's Fashion     82
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 3         57           4        Shoes    Zara    Men's Fashion     23
# 4         79           5      T-shirt  Adidas    Men's Fashion     79
# ..       ...         ...          ...     ...              ...    ...
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 0    1.043159   Black   XL
# 1    4.026416   Black    L
# 2    3.337938  Yellow   XL
# ...

# %% [markdown]
# ## Menampilkan Keseluruhan Data

# %%
print("----------------------------")
print("Menampilkan keseluruhan data")
print("----------------------------")
print(df.to_string())
# Out:
# ----------------------------
# Menampilkan keseluruhan data
# ----------------------------
#      User ID  Product ID Product Name   Brand         Category  Price    Rating   Color Size
# 0         19           1        Dress  Adidas    Men's Fashion     40  1.043159   Black   XL
# 1         97           2        Shoes     H&M  Women's Fashion     82  4.026416   Black    L
# 2         25           3        Dress  Adidas  Women's Fashion     44  3.337938  Yellow   XL
# 3         57           4        Shoes    Zara    Men's Fashion     23  1.049523   White    S
# 4         79           5      T-shirt  Adidas    Men's Fashion     79  4.302773   Black    M
# 5         98           6        Dress  Adidas    Men's Fashion     47  1.379566  Yellow    L
# 6         16           7        Jeans   Gucci    Men's Fashion     37  1.356750   White   XL
# 7         63           8      Sweater    Zara    Kids' Fashion     64  4.360303    Blue   XL
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Data cleaning merupakan proses menghapus atau memodifikasi data yang tidak lengkap, duplikat, tidak akurat, dan salah format. Data-data tersebut dihapus atau dimodifikasi untuk memastikan data yang sedang diolah adalah data berkualitas agar dapat menghasilkan keputusan yang lebih akurat.

# %% [markdown]
# 1. Missing Values (nilai yang hilang atau tidak terbaca)

# %%
print("-----------------------------------")
print("Menampilkan missing values dataset")
print("-----------------------------------")
print(df.isna().sum())
# Out:
# -----------------------------------
# Menampilkan missing values dataset
# -----------------------------------
# User ID         0
# Product ID      0
# Product Name    0
# Brand           0
# Category        0
# Price           0
# Rating          0
# Color           0
# Size            0
# dtype: int64

# %%
print("-----------------------------------------------")
print("Menampilkan missing values dataset dalam persen")
print("-----------------------------------------------")
print((df.isna().sum() / len(df)) * 100)
# Out:
# -----------------------------------------------
# Menampilkan missing values dataset dalam persen
# -----------------------------------------------
# User ID         0.0
# Product ID      0.0
# Product Name    0.0
# Brand           0.0
# Category        0.0
# Price           0.0
# Rating          0.0
# Color           0.0
# Size            0.0
# dtype: float64

# %% [markdown]
# dikarenakan seperti yang terlihat diatas bahwa missing values nya tidak ada data yang hilang atau tidak terbaca, maka dari itu tidak perlu melakukan penanganan terhadap missing values (nilai yang hilang atau tidak terbaca)

# %% [markdown]
# 2. Duplicated Values
#
#  Duplicated Values adalah sebuah kondisi dimana ada data yang muncul beberapa kali dalam satu data set.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [User ID, Product ID, Product Name, Brand, Category, Price, Rating, Color, Size]
# Index: []

# %% [markdown]
# dikarenakan tidak ada data yang muncul beberapa kali dalam satu dataset, maka tidak perlu melakukan penanganan duplicated values dengan menghapus semua duplikasi

# %% [markdown]
# 3. Outliers
#
#  Outliers adalah nilai yang jauh berbeda dari nilai lainnya dalam dataset. Nilai Outlier bisa jauh lebih rendah atau lebih tinggi. Outlier bisa terjadi karena berbagai alasan seperti faktor kesalahan maupun kejadian lain yang tidak terduga.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom       Persentase Outliers
# User ID                     0.0
# Product ID                  0.0
# Price                       0.0
# Rating                      0.0

# %% [markdown]
# dikarenakan tidak ada nilai yang jauh berbeda dari nilai yang lainnya dalam dataset, maka tidak perlu melakukan penanganan terhadap outliers

# %% [markdown]
# 4. Inconsistent Values ( nilai yang tidak konsisten)

# %%
df
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 0         19           1        Dress  Adidas    Men's Fashion     40
# 1         97           2        Shoes     H&M  Women's Fashion     82
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 3         57           4        Shoes    Zara    Men's Fashion     23
# 4         79           5      T-shirt  Adidas    Men's Fashion     79
# ..       ...         ...          ...     ...              ...    ...
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 0    1.043159   Black   XL
# 1    4.026416   Black    L
# 2    3.337938  Yellow   XL
# ...

# %% [markdown]
# dikarenakan tidak adanya data yang inconsistent value, maka tidak perlu melakukan penanganan terhadap inconsistent value

# %% [markdown]
# 5. Construct Data
#
#  Construct Data merujuk pada kegiatan membangun atau menciptakan fitur (features) baru dari data yang
#  ada atau mengubah struktur data agar sesuai dengan kebutuhan analisis atau model data mining yang
#  akan digunakan. Kegiatan ini biasa dilakukan dengan memanipulasi data untuk membuat atribut atau
#  variabel baru yang dapat meningkatkan pemahaman kita tentang fenomena yang diamati atau
#  meningkatkan kinerja model yang akan kita bangun.

# %% [markdown]
# 1. Menentukan kategori ukuran berdasarkan informasi size (Segmentasi Ukuran)
#
#  Kategori ukuran:
#
#  Small -> size (XS, S)
#
#  Medium -> size (M)
#
#  Large -> size (L, XL)

# %%
def categorize_size(size):
    if size in ["XS", "S"]:
        return "Small"
    elif size in ["M"]:
        return "Medium"
    elif size in ["L", "XL"]:
        return "Large"
    else:
        return "Unknown"

df["Size_Category"] = df["Size"].apply(categorize_size)

# %%
print(df.to_string())
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price    Rating   Color Size Size_Category
# 0         19           1        Dress  Adidas    Men's Fashion     40  1.043159   Black   XL         Large
# 1         97           2        Shoes     H&M  Women's Fashion     82  4.026416   Black    L         Large
# 2         25           3        Dress  Adidas  Women's Fashion     44  3.337938  Yellow   XL         Large
# 3         57           4        Shoes    Zara    Men's Fashion     23  1.049523   White    S         Small
# 4         79           5      T-shirt  Adidas    Men's Fashion     79  4.302773   Black    M        Medium
# 5         98           6        Dress  Adidas    Men's Fashion     47  1.379566  Yellow    L         Large
# 6         16           7        Jeans   Gucci    Men's Fashion     37  1.356750   White   XL         Large
# 7         63           8      Sweater    Zara    Kids' Fashion     64  4.360303    Blue   XL         Large
# ...

# %% [markdown]
# 2. Menentukan kategori harga berdasarkan rentang harga (Segmentasi Harga)
#
#  Kategori Harga:
#
#  Low = <30
#
#  Medium = 30 <= price <70
#
#  High = > 70

# %%
def categorize_price(price):
    if price < 30:
        return "Low"
    elif 30 <= price < 70:
        return "Medium"
    else:
        return "High"


df["Price_Category"] = df["Price"].apply(categorize_price)

# %%
print(df.to_string())
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price    Rating   Color Size Size_Category Price_Category
# 0         19           1        Dress  Adidas    Men's Fashion     40  1.043159   Black   XL         Large         Medium
# 1         97           2        Shoes     H&M  Women's Fashion     82  4.026416   Black    L         Large           High
# 2         25           3        Dress  Adidas  Women's Fashion     44  3.337938  Yellow   XL         Large         Medium
# 3         57           4        Shoes    Zara    Men's Fashion     23  1.049523   White    S         Small            Low
# 4         79           5      T-shirt  Adidas    Men's Fashion     79  4.302773   Black    M        Medium           High
# 5         98           6        Dress  Adidas    Men's Fashion     47  1.379566  Yellow    L         Large         Medium
# 6         16           7        Jeans   Gucci    Men's Fashion     37  1.356750   White   XL         Large         Medium
# ...

# %% [markdown]
# 6. Data Reduction
#
#  Data reduction merupakan teknik yang digunakan dalam data mining untuk mengurangi ukuran dataset
#  tetapi tetap menjaga informasi yang penting. Hal ini sangat membantu dalam situasi dimana dataset terlalu
#  besar untuk di proses secara efisien, atau situasi dimana dataset memiliki informasi yang tidak relevan atau
#  informasi yang berulang-ulang.

# %% [markdown]
# Menurut saya kolom-kolom yang tidak relevan dengan studi kasus saya dan saya ingin menghapusnya yaitu kolom User ID dan Product ID

# %%
df = df.drop(['User ID', 'Product ID'], axis=1)

# %%
print(df.to_string())
# Out:
#     Product Name   Brand         Category  Price    Rating   Color Size Size_Category Price_Category
# 0          Dress  Adidas    Men's Fashion     40  1.043159   Black   XL         Large         Medium
# 1          Shoes     H&M  Women's Fashion     82  4.026416   Black    L         Large           High
# 2          Dress  Adidas  Women's Fashion     44  3.337938  Yellow   XL         Large         Medium
# 3          Shoes    Zara    Men's Fashion     23  1.049523   White    S         Small            Low
# 4        T-shirt  Adidas    Men's Fashion     79  4.302773   Black    M        Medium           High
# 5          Dress  Adidas    Men's Fashion     47  1.379566  Yellow    L         Large         Medium
# 6          Jeans   Gucci    Men's Fashion     37  1.356750   White   XL         Large         Medium
# 7        Sweater    Zara    Kids' Fashion     64  4.360303    Blue   XL         Large         Medium
# ...
